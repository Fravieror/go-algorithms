# %% [markdown]
# Complexity Analysis
# Depth-First Traversal (Inorder, Preorder, Postorder):
#
# Time Complexity:
# 𝑂
# (
# 𝑛
# )
# O(n) where
# 𝑛
# n is the number of nodes in the tree. Each node is visited once.
# Space Complexity:
# Recursive:
# 𝑂
# (
# ℎ
# )
# O(h) where
# ℎ
# h is the height of the tree due to the recursion stack.
# Non-Recursive:
# 𝑂
# (
# ℎ
# )
# O(h) due to the explicit stack used for traversal.
# Breadth-First Traversal (Level Order):
#
# Time Complexity:
# 𝑂
# (
# 𝑛
# )
# O(n) where
# 𝑛
# n is the number of nodes in the tree. Each node is visited once.
# Space Complexity:
# 𝑂
# (
# 𝑤
# )
# O(w) where
# 𝑤
# w is the maximum width of the tree. In the worst case, this can be
# 𝑂
# (
# 𝑛
# )
# O(n) if the tree is very wide.

# %% [markdown]
#         4
#        / \
#       2   6
#      / \ / \
#     1  3 5  7
#
# Inorder Traversal (Left, Root, Right)
# Visit the left subtree
# Visit the root node
# Visit the right subtree
# Order: 1, 2, 3, 4, 5, 6, 7
#
# Preorder Traversal (Root, Left, Right)
# Visit the root node
# Visit the left subtree
# Visit the right subtree
# Order: 4, 2, 1, 3, 6, 5, 7
#
# Postorder Traversal (Left, Right, Root)
# Visit the left subtree
# Visit the right subtree
# Visit the root node
# Order: 1, 3, 2, 5, 7, 6, 4
